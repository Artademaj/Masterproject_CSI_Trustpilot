# %%
#Check current working directory and import packages
import os
wd = os.getcwd() 
print(wd)

import sqlalchemy
from sqlalchemy import create_engine
import pandas as pd
import psycopg2
import plotly.express as px
import datetime
# Out:
# /Users/Arta/_trustpilot/trustpilot

# %%
#Create database connection and read tables
engine = create_engine('postgresql://localhost/')

#Read table houses from Database
reviews_food_beverages_tobacco = pd.read_sql_table(
    "reviews_food_beverages_tobacco",
    con=engine
)

# %%
reviews_food_beverages_tobacco
# Out:
#               company                      category total_reviews  \
# 0        Epic Cellars                   Wine Cellar           786
# 1        Epic Cellars                   Wine Cellar           786
# 2        Epic Cellars                   Wine Cellar           786
# 3        Epic Cellars                   Wine Cellar           786
# 4        Epic Cellars                   Wine Cellar           786
# ...               ...                           ...           ...
# 546272  HelloFresh US  Online Food Ordering Service        38,695
# 546273  HelloFresh US  Online Food Ordering Service        38,695
# 546274  HelloFresh US  Online Food Ordering Service        38,695
# 546275  HelloFresh US  Online Food Ordering Service        38,695
# 546276  HelloFresh US  Online Food Ordering Service        38,695
#
#        general_rating review_rating  \
# 0                   5             5
# 1                   5             5
# 2                   5             5
# 3                   5             5
# 4                   5             5
# ...               ...           ...
# 546272            4.4             1
# 546273            4.4             2
# 546274            4.4             1
# 546275            4.4             2
# 546276            4.4             3
#
#                                               review_text
# 0       A very easy and pleasant experience. The whole...
# 1       Great customer service and communication. Made...
# 2       From the first time reaching out to them to th...
# 3       Highly recommend. Very easy to work with, and ...
# 4       We absolutely loved dealing with Epic Cellars!...
# ...                                                   ...
# 546272  I just want to say again. NO CUSTOMER SERVICE ...
# 546273  I tried Hello Fresh out of curiosity. I liked ...
# 546274  First time customer of Hello Fresh and came ho...
# 546275  My first box was great and I thought I would r...
# 546276  I loved HelloFresh after my first delivery. Yo...
#
# [546277 rows x 6 columns]
